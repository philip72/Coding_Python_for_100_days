# %%
import random
cards= [11,2,3,4,5,6,7,8,9,10,10,10,10]

game_on=True
computer_cards=random.choices(cards, k=2)
user_cards=random.choices(cards, k=2)

print(f'These are your cards {user_cards} and this is one computers cards {computer_cards[0]}')

while game_on:
    if sum(computer_cards)==21:
        print(f'Computer has already 21 ')
        game_on=False
    elif sum(user_cards)==21:
        print(f'User wins')
        game_on=False
    elif sum(user_cards)>21:
        print(f'Computer wins because usre is over 21')
        game_on=False
    elif sum(computer_cards)>21:
        print('You win because computer is over 21')
        game_on=False
    
    cont=input('Do you wish to continue? ').lower()

    if cont=='yes':
        user_cards.append(random.choice(cards))
        print(user_cards)
        if sum(user_cards)>21:
            print(f'Computer wins because usre is over 21')
            game_on=False
    
    print(f'These are the cards users:{user_cards} and computers:{computer_cards}')

    if sum(computer_cards)<17:
        computer_cards.append(random.choice(cards))
        if sum(computer_cards)>21:
            print('You win because computer is over 21')
            game_on=False
    
    if sum(computer_cards)>sum(user_cards):
        print('Computer won')
    elif sum(computer_cards)<sum(user_cards):
        print('You win')
    else: 
        print('draw')
    game_on=False






# print(user_cards, computer_cards)

# if sum(user_cards)==21 or sum(computer_cards)==21:
#     print('game ends')
# elif sum(user_cards)>21 or sum(computer_cards)>21:
#     print('game ends')

# print(sum(user_cards))
# cont=input('Do you wish to get another card')

# if cont== 'yes':
#     user_cards.append(random.choice(cards))
#     print(user_cards)
# else:
#     print('game_ends')

# if sum(computer_cards)<17:
#     computer_cards.append(random.choice(cards))
#     print(computer_cards)
user_total=0
for i in user_cards:
    user_total+=i
print(user_total)

#print(random.choices(cards, k=2))
# Out:
# These are your cards [2, 10] and this is one computers cards 11
# Computer has already 21
# [2, 10, 9]
# These are the cards users:[2, 10, 9] and computers:[11, 10]
# draw
# 21

# %%
import random

def deal_card():
    """Return a random card from the deck."""
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    return random.choice(cards)  

def calculate_score(cards):
    
    if sum(cards)==21 and len(cards)==2:
        return 0
    if sum(cards)>21 and 11 in cards:
        cards.remove(11)
        cards.append(1)
    return sum(cards)

user_card=[]
computer_card=[]

for _ in range(2):
    user_card.append(deal_card())
    computer_card.append(deal_card())


user_score= calculate_score(user_card)
computer_card=calculate_score(computer_card)

if user_score == 0 or computer_score==0 or user_score>21:
    is_game_over=True

# %%
import random

def deal_card():
    """Return a random card from the deck."""
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    return random.choice(cards)

def calculate_score(cards):
    """Calculate the total value of a hand of cards."""
    if sum(cards) == 21 and len(cards) == 2:
        return 0  # Blackjack
    if 11 in cards and sum(cards) > 21:
        cards.remove(11)
        cards.append(1)
    return sum(cards)

def compare(user_score, computer_score):
    """Compare the scores and determine the winner."""
    if user_score == computer_score:
        return "It's a draw."
    elif computer_score == 0:
        return "Computer has Blackjack. You lose."
    elif user_score == 0:
        return "You have Blackjack. You win!"
    elif user_score > 21:
        return "You went over. You lose."
    elif computer_score > 21:
        return "Computer went over. You win!"
    elif user_score > computer_score:
        return "You win!"
    else:
        return "You lose."

def play_game():
    print("Welcome to Blackjack!")

    user_cards = [deal_card(), deal_card()]
    computer_cards = [deal_card(), deal_card()]
    game_over = False

    while not game_over:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)

        print(f"Your cards: {user_cards}, current score: {user_score}")
        print(f"Computer's first card: {computer_cards[0]}")

        if user_score == 0 or computer_score == 0 or user_score > 21:
            game_over = True
        else:
            should_continue = input("Type 'y' to get another card, 'n' to pass: ").lower()
            if should_continue == 'y':
                user_cards.append(deal_card())
            else:
                game_over = True

    while computer_score != 0 and computer_score < 17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)

    print(f"Your final hand: {user_cards}, final score: {user_score}")
    print(f"Computer's final hand: {computer_cards}, final score: {computer_score}")
    print(compare(user_score, computer_score))

# Start the game
play_game()
